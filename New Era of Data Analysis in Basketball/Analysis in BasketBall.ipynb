# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

judge = pd.read_csv('datasets/judge.csv')

stanton = pd.read_csv('datasets/stanton.csv')

# %%
# judge.head()
# to display all column(sometime pandas collapse some column)
pd.set_option('display.max_columns',None)

# judge.head()
# print(judge)

# to display last five column
judge.tail()
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 3431         CH  2016-08-13           85.6        -1.9659         5.9113
# 3432         CH  2016-08-13           87.6        -1.9318         5.9349
# 3433         CH  2016-08-13           87.2        -2.0285         5.8656
# 3434         CU  2016-08-13           79.7        -1.7108         6.1926
# 3435         FF  2016-08-13           93.2        -1.8476         6.0063
#
#       player_name  batter  pitcher    events          description  spin_dir  \
# 3431  Aaron Judge  592450   542882       NaN                 ball       NaN
# 3432  Aaron Judge  592450   542882  home_run  hit_into_play_score       NaN
# 3433  Aaron Judge  592450   542882       NaN                 ball       NaN
# 3434  Aaron Judge  592450   542882       NaN                 foul       NaN
# 3435  Aaron Judge  592450   542882       NaN        called_strike       NaN
#
# ...

# %%
# All of Aaron Judge's batted ball events in 2017


judge_events_2017=judge[judge['game_date'].apply(lambda x:x[:4]) == '2017']['events']
# judge_events_2017 = judge[judge['game_date'].apply(lambda x: x[:4]) == '2017']['events']
# for i in range(len(judge)): if(judge[i]['game_date'][:4] == '2017'): li.append(judge[i]['events'])
print("Aron judge batted ball event total,2017:")
print(judge_events_2017.value_counts())

# stanton

stanton_events_2017=stanton[stanton['game_date'].apply(lambda x: x[:4])=='2017']["events"]
print('stanton judge batted ball eveny total,2017:')
print(stanton_events_2017.value_counts())
# Out:
# Aron judge batted ball event total,2017:
# strikeout                    207
# field_out                    146
# walk                         116
# single                        75
# home_run                      52
# double                        24
# grounded_into_double_play     15
# force_out                     11
# intent_walk                   11
# hit_by_pitch                   5
# sac_fly                        4
# fielders_choice_out            4
# field_error                    4
# triple                         3
# strikeout_double_play          1
# Name: events, dtype: int64
# stanton judge batted ball eveny total,2017:
# field_out                    239
# strikeout                    161
# single                        77
# walk                          72
# home_run                      59
# double                        32
# intent_walk                   13
# grounded_into_double_play     13
# force_out                      7
# hit_by_pitch                   7
# ...

# %%
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
# Filter to include home runs only

judge_hr = judge[judge['events']=='home_run']
stanton_hr = stanton[stanton['events']=='home_run']


# Create a figure with two scatter plots of launch speed vs. launch angle, one for each player's home runs
# satter plot

fig1,axs1=plt.subplots(ncols=2,sharex=True,sharey=True)
sns.regplot(x='launch_speed', y='launch_angle', fit_reg=False, color='tab:blue', data=judge_hr, ax=axs1[0]).set_title('judge\nHome Runs')
sns.regplot(x='launch_speed',y='launch_angle',fit_reg=False,color='tab:blue',data=stanton_hr,ax=axs1[1]).set_title('stanton\nHome Run')


# Create a figure with two KDE plots of launch speed vs. launch angle, one for each player's home runs
# KDE plot


fig2,axs2 = plt.subplots(ncols=2,sharex=True,sharey=True)
x=judge_hr['launch_speed']
y=judge_hr['launch_angle']
sns.kdeplot(x,y,ax=axs2[0],shade=True,cmap='Blues',shade_lowest=False).set_title('judge\nHome Runs')
x=stanton_hr['launch_speed']
y=stanton_hr['launch_angle']
sns.kdeplot(x,y,cmap='Blues',shade=True,shade_lowes=False,ax=axs2[1]).set_title('stanton\nHome Run')
# Out:
# c:\users\ramen\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# c:\users\ramen\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'shade_lowes'
#   cset = contour_func(
# Text(0.5, 1.0, 'stanton\nHome Run')

# %% [markdown]
# ## 5.Home Run by pitch velocity

# %%
# Combine the Judge and Stanton home run DataFrames for easy boxplot plotting

judge_stanton_hr = pd.concat([judge_hr,stanton_hr])

# Create a boxplot that describes the pitch velocity of each player's home runs
x='player_name'
y='release_speed'

sns.boxplot(x,y,data=judge_stanton_hr,color='tab:blue').set_title('Home Runs,2015-2017')
# Out:
# Text(0.5, 1.0, 'Home Runs,2015-2017')

# %% [markdown]
# ## Home run by pitch loaction 1

# %%
def assign_x_coord(row):
    if row.zone in [1,4,7]:
        return 1
    if row.zone in [2,5,8]:
        return 2
    if row.zone in [3,6,9]:
        return 3

# %% [markdown]
# ## Home run by pitch lacation 2

# %%
def assign_y_coord(row):
    if row.zone in  [1,2,3]:
        return 3
    if row.zone in [4,5,6]:
        return 2
    if row.zone in [7,8,9]:
        return 1

# %% [markdown]
# ## 8. Aaron Judge's home run zone
#
# Now we can apply the functions we've created then construct our 2D histograms. First, for Aaron Judge (again, for pitches in the strike zone that resulted in home runs).

# %%
#to create histogram

judge_strike_hr = judge_hr.copy().loc[judge_hr.zone <=9]

#assign cartesian co-ordinates
judge_strike_hr['zone_x'] = judge_strike_hr.apply(assign_x_coord,axis=1)
judge_strike_hr['zone_y']=judge_strike_hr.apply(assign_y_coord,axis=1)

# plot judge's home run zone as 2d histogram with color bar

plt.hist2d(judge_strike_hr['zone_x'],judge_strike_hr['zone_y'],bins=3,cmap='Blues')
plt.gca().get_xaxis().set_visible(False)
plt.gca().get_yaxis().set_visible(False)
cb = plt.colorbar()
cb.set_label("Counts in Bin")

# %%
# same for stanton

stanton_strike_hr=stanton_hr.copy().loc[stanton_hr.zone <=9]

stanton_strike_hr['zone_x'] = stanton_strike_hr.apply(assign_x_coord,axis=1)
stanton_strike_hr['zone_y'] = stanton_strike_hr.apply(assign_y_coord,axis=1)

plt.hist2d(stanton_strike_hr['zone_x'],stanton_strike_hr['zone_y'],bins=3,cmap='Blues')
plt.gca().get_xaxis().set_visible(False)
plt.gca().get_yaxis().set_visible(False)
cb = plt.colorbar()
cb.set_label("Counts in Bin")

# %%
should_pitchers_be_scared = True
